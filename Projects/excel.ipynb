# %% [markdown]
# # Статистический анализ данных
# ## Учебный проект в Excel
#
# 1. группировка и обработка данных;
# 2. расчёт описательных статистик;
# 3. проверка статистических гипотез;
# 4. корреляционный анализ;
# 5. анализ временных рядов;
# 6. применение скользящего среднего и экспоненциального сглаживания;
# 7. интерпретация результатов.
#
#
# ### Используемые технологии: MS Excel.

# %% [markdown]
# # Скриншоты проекта
#
# ## Исходные данные
# ![Исходные данные](photos/stat/ish.jpg)
#
# ## Отклонения
# ![Отклонения](photos/stat/otkl.jpg)
#
# ## Группировка и графическое представление
# ![Группировка и графическое представление](photos/stat/group.jpg)
#
# ![Группировка и графическое представление](photos/stat/group3.jpg)
#
# ## Проверка гипотезы о нормальном законе распределения с помощью группировки
# ![Проверка гипотезы о нормальном законе распределения с помощью группировки](photos/stat/norm.jpg)
#
# ## Проверка гипотезы о нормальном законе распределения по свойствам нормального распределения
# ![Проверка гипотезы о нормальном законе распределения по свойствам нормального распределения](photos/stat/norm2.jpg)
#
# ## Проверка гипотезы о нормальном законе распределения по формулам Пустыльника
# ![Проверка гипотезы о нормальном законе распределения по формулам Пустыльника](photos/stat/norm3.jpg)
#
# ## Проверка гипотезы о нормальном законе распределения с помощью критерия Пирсона
# ![Проверка гипотезы о нормальном законе распределения с помощью критерия Пирсона](photos/stat/norm4.jpg)
#
# ## Проверка гипотезы о равенстве дисперсий с помощью F-критерия Фишера
# ![Проверка гипотезы о равенстве дисперсий с помощью F-критерия Фишера](photos/stat/ftest.jpg)
#
# ## Проверка гипотезы о равенстве средних с помощью t-критерия Стьюдента
# ![Проверка гипотезы о равенстве средних с помощью t-критерия Стьюдента](photos/stat/t-test.jpg)
#
# ## Расчеты
# ![Расчеты](photos/stat/rasch.jpg)
#
# ## Исследование взаимосвязи двух величин с помощью диаграммы рассеяния и коэффициента корреляции
# ![Исследование взаимосвязи двух величин с помощью диаграммы рассеяния и коэффициента корреляции](photos/stat/vz-svz.jpg)
