# %% [markdown]
# # Проектирование базы данных и SQL
# ## Учебный проект по разработке информационной системы для бюро трудоустройства
#
# 1. анализ предметной области;
# 2. разработка инфологической и реляционной моделей;
# 3. проектирование структуры БД;
# 4. создание таблиц, ключей и связей;
# 5. написание SQL-запросов;
# 6. использование JOIN, GROUP BY, HAVING, подзапросов и UNION;
# 7. разработка пользовательских форм.
#
# ### Используемые технологии: SQL, MS Access, ER-моделирование.

# %% [markdown]
# # Скриншоты проекта
#
# ## ER-диаграмма базы данных
# ![ER-диаграмма базы данных](photos/database/er1.png)
#
# ## Вырезка из таблицы вакансий
# ![Вырезка из таблицы вакансий](photos/database/table.png)
#
# ## Пример SQL запроса
# ![Пример SQL запроса](photos/database/SQL.jpg)
#
# ## Главное меню экранной формы
# ![Главное меню экранной формы](photos/database/main.png)
#
# ## Личный кабинет работника бюро
# ![Личный кабинет работника бюро](photos/database/lk.png)
#
# ## Форма соискателей
# ![Форма соискателей](photos/database/form.png)
#
# ## Свободные соискатели (форма сформирована через SQL-запрос)
# ![Свободные соискатели](photos/database/free.png)
